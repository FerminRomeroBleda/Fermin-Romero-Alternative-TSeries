# %% [markdown]
# # Alternative Time Series
#
# ---

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

from statsmodels.tsa.stattools import adfuller

from statsmodels.graphics.tsaplots import plot_acf

from pmdarima import auto_arima

# %%
df = pd.read_csv("https://raw.githubusercontent.com/4GeeksAcademy/alternative-time-series-project/main/sales.csv")
df.head(3)
# Out:
#                          date      sales
# 0  2022-09-03 17:10:08.079328  55.292157
# 1  2022-09-04 17:10:08.079328  53.803211
# 2  2022-09-05 17:10:08.079328  58.141693

# %% [markdown]
# # Construct and analyze the time serie
#
# Construct the valid data structure for the time serie, graph it, and then analyze it and answer the following questions:
#
# Which is the tensor of the time serie?
#
# Which is the trend?
#
# Is it stationary?
#
# Is there variability or noise?
#
# >Note: A tensor in a time serie is the minimum unit of time for which there is data. It can be every second, minute, hour, day, week, month...

# %%
df['date'] = pd.to_datetime(df.date)

df = df.set_index('date') # Set column 'date' as INDEX

ts = df.sales

ts.head()
# Out:
# date
# 2022-09-03 17:10:08.079328    55.292157
# 2022-09-04 17:10:08.079328    53.803211
# 2022-09-05 17:10:08.079328    58.141693
# 2022-09-06 17:10:08.079328    64.530899
# 2022-09-07 17:10:08.079328    66.013633
# Name: sales, dtype: float64

# %%
fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)

plt. tight_layout()

plt.show()

# %% [markdown]
# ## Analysis of a time series

# %% [markdown]
# ### decomposition of the series

# %%
# Period : si tenemos datos cada hora period = 60 (minutos en una hora)
# si tenemos datos cada día period = 30 (días en un mes)
# si tenemos datos cada mes period = 12 (meses en un año)
# si tenemos datos cada año period = 1

# En este caso tenemos datos cada día, entonces period = 30

decomposition = seasonal_decompose(ts, period = 30)
decomposition

# %% [markdown]
# ### trend analysis

# %%
trend = decomposition.trend

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = trend)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Seasonality analysis

# %%
seasonal = decomposition.seasonal

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = seasonal)

plt.tight_layout()

plt.show()

# %%
def test_stationarity(timeseries):

    print("Dickey-Fuller test results:")

    dftest = adfuller(timeseries, autolag = "AIC")
    dfoutput = pd.Series(dftest[0:4], index = ["Test Statistic", "p-value", "#Lags Used", "Number of Observations Used"])

    for key,value in dftest[4].items():

        dfoutput["Critical Value (%s)"%key] = value
        
    return dfoutput

test_stationarity(ts)

# lo que más nos importa el es p-valor (parte de contrastes de hipótesis)
# Hipótesis nula rechazada (que la serie es estacionaria)
# como p-valor es mayor de 0.05 se rechaza ( por que?)
# Out:
# Dickey-Fuller test results:
# Test Statistic                   0.545414
# p-value                          0.986190
# #Lags Used                      13.000000
# Number of Observations Used    352.000000
# Critical Value (1%)             -3.449065
# Critical Value (5%)             -2.869786
# Critical Value (10%)            -2.571163
# dtype: float64

# %% [markdown]
# Here we can see that the p-value is greater than 0.05, which means that our null hypothesis will be rejected, and we will take this series as non-stationary.

# %% [markdown]
# ### Analysis of variability

# %%
# Como fluctua la serie temporal en el tiempo
# Se tiene en cuenta tanto la tendencia como la estacionalidad

# calcula residuos

residual = decomposition.resid

fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts)
sns.lineplot(data = residual)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Autocorrelation analysis

# %%
# correlacion: cuanto explico yo la relación de una variable respecto a otra

plot_acf(ts)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Model training

# %%
ts_stationary = ts.diff().dropna() # Convertir a estacionaria

test_stationarity(ts_stationary)
# Out:
# Dickey-Fuller test results:
# Test Statistic                -9.430263e+00
# p-value                        5.212954e-16
# #Lags Used                     1.200000e+01
# Number of Observations Used    3.520000e+02
# Critical Value (1%)           -3.449065e+00
# Critical Value (5%)           -2.869786e+00
# Critical Value (10%)          -2.571163e+00
# dtype: float64

# %%
# ARIMA (p, d, q)

from pmdarima import auto_arima

model = auto_arima(ts_stationary, seasonal = True, trace = True, m = 12)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=1847.121, Time=1.38 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=2096.542, Time=0.02 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=1972.854, Time=0.21 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=inf, Time=0.70 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=2209.657, Time=0.01 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=1845.127, Time=0.87 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=1843.048, Time=0.60 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=1845.092, Time=1.03 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=1843.587, Time=0.25 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=1841.533, Time=0.51 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=1843.435, Time=1.41 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=1843.433, Time=1.21 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=1.29 sec
# ...

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  365
# Model:               SARIMAX(1, 0, 1)   Log Likelihood                -915.776
# Date:                Wed, 27 Nov 2024   AIC                           1839.553
# Time:                        11:59:32   BIC                           1855.152
# Sample:                    09-04-2022   HQIC                          1845.752
#                          - 09-03-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      2.8110      0.134     21.055      0.000       2.549       3.073
# ar.L1         -0.0821      0.052     -1.592      0.111      -0.183       0.019
# ma.L1         -0.9413      0.020    -47.701      0.000      -0.980      -0.903
# ...

# %% [markdown]
# ## Model Prediction

# %%
forecast = model.predict(30) # Next 30 days
forecast
# Out:
# 2023-09-04 17:10:08.079328    1.675366
# 2023-09-05 17:10:08.079328    2.673520
# 2023-09-06 17:10:08.079328    2.591621
# 2023-09-07 17:10:08.079328    2.598341
# 2023-09-08 17:10:08.079328    2.597789
# 2023-09-09 17:10:08.079328    2.597834
# 2023-09-10 17:10:08.079328    2.597831
# 2023-09-11 17:10:08.079328    2.597831
# 2023-09-12 17:10:08.079328    2.597831
# 2023-09-13 17:10:08.079328    2.597831
# 2023-09-14 17:10:08.079328    2.597831
# 2023-09-15 17:10:08.079328    2.597831
# 2023-09-16 17:10:08.079328    2.597831
# 2023-09-17 17:10:08.079328    2.597831
# 2023-09-18 17:10:08.079328    2.597831
# 2023-09-19 17:10:08.079328    2.597831
# 2023-09-20 17:10:08.079328    2.597831
# 2023-09-21 17:10:08.079328    2.597831
# 2023-09-22 17:10:08.079328    2.597831
# 2023-09-23 17:10:08.079328    2.597831
# 2023-09-24 17:10:08.079328    2.597831
# 2023-09-25 17:10:08.079328    2.597831
# 2023-09-26 17:10:08.079328    2.597831
# 2023-09-27 17:10:08.079328    2.597831
# ...

# %%
fig, axis = plt.subplots(figsize = (10, 5))

sns.lineplot(data = ts_stationary)
sns.lineplot(data = forecast, c = "green")

plt.tight_layout()

plt.show()
